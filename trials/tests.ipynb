# %% [markdown]
# ### Will use to keep track of tests (other notebooks are getting messy)
# #### A few notes:
# - Our monte carlo will always be 1000 sims
# - Our noise is added random gaussian noise to the dataset
# - We are using a probabaility rank matrix where each entry (i, j) is "the probability that there are at least k closer points to i than j is"
# - We will be doing 3 trials for our probability rank matrix simulation, because of the randomness of our monte carlo (we want to make sure we didn't just get lucky) (# of trials might change in the future)

# %% [markdown]
# #### Test 1:
# ##### Noise level of 1.0:
# - vanilla HDBSCAN:
# - HDBSCAN with probabaility rank matrix: 1: 2: 3: avg:
